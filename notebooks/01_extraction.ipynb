# %% [markdown]
# # 01: Data Extraction
# This notebook documents the initial loading and inspection of the Diabetes 130-US Hospitals dataset.

# %% [markdown]
# ## Import Libraries
# Loading the core data manipulation library.

# %%
import pandas as pd

# %% [markdown]
# ## Load Raw Data
# Reading the dataset from the local `data/raw/` directory.

# %%
raw_data_path = '../data/raw/diabetic_data.csv'
df = pd.read_csv(raw_data_path)
df.head()

# %% [markdown]
# ## Dataset Overview
# Checking dimensions and initial statistics.

# %%
df.info()
df.describe()
